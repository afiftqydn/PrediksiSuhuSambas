# %%
import warnings
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Overview Data

# %%
#load dataset
data = pd.read_excel("dataset cuaca.xlsx", header=1, index_col=None)
data.head()
# Out:
#       Tanggal    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-07-2023  24.3  33.2  27.1    90.0   1.9  2.8   4.0  300.0     1.0
# 1  02-07-2023  24.3  29.8  26.5    91.0  24.3  2.7   3.0  130.0     0.0
# 2  03-07-2023  24.0  34.0  27.9    86.0   3.4  0.4   3.0   70.0     1.0
# 3  04-07-2023  24.2  34.2  28.4    82.0   0.0  4.2   3.0  300.0     1.0
# 4  05-07-2023  24.2  32.2  27.4    88.0   0.0  7.7   4.0  280.0     1.0
#
#   ddd_car
# 0      SE
# 1      C
# 2      C
# 3      C
# 4      C

# %%
data.shape
# Out:
# (382, 11)

# %%
data.tail(18)
# Out:
#                                                Tanggal    Tn    Tx  Tavg  \
# 364                                         29-06-2024  23.6  32.8  26.8
# 365                                         30-06-2024  23.8  33.3  26.3
# 366                                                NaN   NaN   NaN   NaN
# 367                                                NaN   NaN   NaN   NaN
# 368                                                NaN   NaN   NaN   NaN
# 369                                       Keterangan :   NaN   NaN   NaN
# 370                           8888: data tidak terukur   NaN   NaN   NaN
# 371  9999: Tidak Ada Data (tidak dilakukan pengukuran)   NaN   NaN   NaN
# 372                      Tn: Temperatur minimum\t (°C)   NaN   NaN   NaN
# 373                       Tx: Temperatur maksimum (°C)   NaN   NaN   NaN
# 374                    Tavg: Temperatur rata-rata (°C)   NaN   NaN   NaN
# 375                   RH_avg: Kelembapan rata-rata (%)   NaN   NaN   NaN
# ...

# %%
data = data[:-16]

# %%
data.tail(15)
# Out:
#         Tanggal    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 351  16-06-2024  23.8  33.3  27.5    87.0   0.4  7.9   5.0  260.0     1.0
# 352  17-06-2024  24.5  33.5  28.1    85.0   0.0  5.6   2.0  170.0     1.0
# 353  18-06-2024  24.9  31.9  27.2    90.0   0.2  5.7   2.0  170.0     1.0
# 354  19-06-2024  24.3  33.3  27.9    84.0   0.9  1.2   3.0   90.0     1.0
# 355  20-06-2024  24.0  28.8  26.1    92.0   0.0  4.4   2.0  170.0     0.0
# 356  21-06-2024  24.2  32.0  27.0    88.0   0.0  0.0   3.0  160.0     1.0
# 357  22-06-2024  23.3  31.2  26.7    88.0  12.4  0.3   6.0  290.0     2.0
# 358  23-06-2024  23.6  31.7  26.6    86.0   9.1  2.7   2.0  140.0     1.0
# 359  24-06-2024  23.7  33.4  28.0    84.0   0.0  1.9   4.0  320.0     1.0
# 360  25-06-2024  24.0  33.7  28.2    85.0   0.0  7.3   4.0  330.0     1.0
# 361  26-06-2024  24.7  33.0  27.7    89.0   0.0  8.2   3.0   70.0     1.0
# 362  27-06-2024  24.2  32.1  27.1    90.0  21.0  4.5   4.0  330.0     1.0
# ...

# %%
data.head()
# Out:
#       Tanggal    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 0  01-07-2023  24.3  33.2  27.1    90.0   1.9  2.8   4.0  300.0     1.0
# 1  02-07-2023  24.3  29.8  26.5    91.0  24.3  2.7   3.0  130.0     0.0
# 2  03-07-2023  24.0  34.0  27.9    86.0   3.4  0.4   3.0   70.0     1.0
# 3  04-07-2023  24.2  34.2  28.4    82.0   0.0  4.2   3.0  300.0     1.0
# 4  05-07-2023  24.2  32.2  27.4    88.0   0.0  7.7   4.0  280.0     1.0
#
#   ddd_car
# 0      SE
# 1      C
# 2      C
# 3      C
# 4      C

# %%
data.shape
# Out:
# (366, 11)

# %% [markdown]
# ### Checking Missing Values

# %%
data.isnull().sum()
# Out:
# Tanggal    0
# Tn         2
# Tx         4
# Tavg       4
# RH_avg     4
# RR         3
# ss         5
# ff_x       2
# ddd_x      2
# ff_avg     2
# ddd_car    2
# dtype: int64

# %%
# Jumlah baris dengan minimal satu missing value
jumlah_baris_missing = data.isnull().any(axis=1).sum()

print(f"Jumlah baris yang mengandung missing value: {jumlah_baris_missing}")
# Out:
# Jumlah baris yang mengandung missing value: 9

# %%
data[data.isnull().any(axis=1)]
# Out:
#         Tanggal    Tn    Tx  Tavg  RH_avg      RR   ss  ff_x  ddd_x  ff_avg  \
# 20   21-07-2023  23.2  31.4  26.5    90.0    26.5  NaN   5.0  160.0     1.0
# 25   26-07-2023  24.2  34.6   NaN     NaN     0.0  7.1   4.0  260.0     2.0
# 31   01-08-2023  24.3  33.4  28.4    86.0     NaN  9.8   3.0  300.0     1.0
# 32   02-08-2023   NaN   NaN   NaN     NaN     NaN  NaN   NaN    NaN     NaN
# 54   24-08-2023  23.8  32.6  26.9    88.0     2.8  NaN   3.0  180.0     1.0
# 97   06-10-2023  24.4   NaN  26.9    92.0     0.0  0.0   3.0  280.0     0.0
# 114  23-10-2023   NaN   NaN   NaN     NaN     NaN  NaN   NaN    NaN     NaN
# 117  26-10-2023  23.7   NaN   NaN     NaN  8888.0  5.2   2.0   90.0     1.0
# 205  22-01-2024  24.8  33.1  27.4    88.0     0.0  NaN   4.0  290.0     1.0
#
#     ddd_car
# 20       C
# 25       S
# 31       C
# 32      NaN
# 54       C
# 97       C
# 114     NaN
# 117      C
# 205      C

# %% [markdown]
# ### Handling

# %% [markdown]
# #### Handling Missing Value

# %%
data = data.dropna().reset_index(drop=True)

# %%
data = data[data['RR'] != 8888]

# %%
print(data.isin([8888]).sum())
# Out:
# Tanggal    0
# Tn         0
# Tx         0
# Tavg       0
# RH_avg     0
# RR         0
# ss         0
# ff_x       0
# ddd_x      0
# ff_avg     0
# ddd_car    0
# dtype: int64

# %%
print(data.isin([9999]).sum())
# Out:
# Tanggal    0
# Tn         0
# Tx         0
# Tavg       0
# RH_avg     0
# RR         0
# ss         0
# ff_x       0
# ddd_x      0
# ff_avg     0
# ddd_car    0
# dtype: int64

# %%
data.isnull().sum()
# Out:
# Tanggal    0
# Tn         0
# Tx         0
# Tavg       0
# RH_avg     0
# RR         0
# ss         0
# ff_x       0
# ddd_x      0
# ff_avg     0
# ddd_car    0
# dtype: int64

# %%
data.shape
# Out:
# (342, 11)

# %% [markdown]
# #### Handling Tipe Data

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  342 non-null    object
#  1   Tn       342 non-null    float64
#  2   Tx       342 non-null    float64
#  3   Tavg     342 non-null    float64
#  4   RH_avg   342 non-null    float64
#  5   RR       342 non-null    float64
#  6   ss       342 non-null    float64
#  7   ff_x     342 non-null    float64
#  8   ddd_x    342 non-null    float64
#  9   ff_avg   342 non-null    float64
#  10  ddd_car  342 non-null    object
# dtypes: float64(9), object(2)
# memory usage: 29.5+ KB

# %%
data['Tanggal'] = pd.to_datetime(data['Tanggal'], dayfirst=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  342 non-null    datetime64[ns]
#  1   Tn       342 non-null    float64
#  2   Tx       342 non-null    float64
#  3   Tavg     342 non-null    float64
#  4   RH_avg   342 non-null    float64
#  5   RR       342 non-null    float64
#  6   ss       342 non-null    float64
#  7   ff_x     342 non-null    float64
#  8   ddd_x    342 non-null    float64
#  9   ff_avg   342 non-null    float64
#  10  ddd_car  342 non-null    object
# dtypes: datetime64[ns](1), float64(9), object(1)
# memory usage: 29.5+ KB

# %%
data.sample(10)
# Out:
#        Tanggal    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  ff_avg  \
# 227 2024-03-02  24.7  28.0  25.7    96.0  68.2  0.0   2.0  100.0     0.0
# 216 2024-02-19  25.0  32.5  27.4    88.0   0.0  3.8   3.0   70.0     1.0
# 90  2023-10-11  24.2  32.8  27.6    85.0   1.4  5.7   5.0  300.0     1.0
# 164 2023-12-27  24.3  31.8  27.5    88.0   5.4  4.5   3.0  210.0     1.0
# 213 2024-02-16  25.0  28.1  25.5    96.0  35.0  0.4   3.0   50.0     1.0
# 55  2023-09-03  24.8  34.4  28.8    75.0   0.0  6.7   4.0  180.0     2.0
# 335 2024-06-24  23.7  33.4  28.0    84.0   0.0  1.9   4.0  320.0     1.0
# 236 2024-03-11  24.4  30.9  27.0    89.0   0.0  4.6   3.0  350.0     1.0
# 255 2024-04-02  24.6  32.7  27.9    85.0   0.0  5.4   3.0  300.0     1.0
# 220 2024-02-24  23.0  32.8  27.8    85.0   0.0  8.8   4.0  290.0     1.0
#
#     ddd_car
# 227      C
# 216      C
# 90       C
# 164      C
# 213      C
# 55       S
# 335      C
# 236      C
# 255      C
# 220      C

# %%
data2 = data.copy()

# %%
data2.to_csv("readyEda.csv", index=1)

# %% [markdown]
# ### EDA

# %%
data2 = pd.read_csv('readyEda.csv')

# %%
data2.head()
# Out:
#    Unnamed: 0     Tanggal    Tn    Tx  Tavg  RH_avg    RR   ss  ff_x  ddd_x  \
# 0           0  2023-07-01  24.3  33.2  27.1    90.0   1.9  2.8   4.0  300.0
# 1           1  2023-07-02  24.3  29.8  26.5    91.0  24.3  2.7   3.0  130.0
# 2           2  2023-07-03  24.0  34.0  27.9    86.0   3.4  0.4   3.0   70.0
# 3           3  2023-07-04  24.2  34.2  28.4    82.0   0.0  4.2   3.0  300.0
# 4           4  2023-07-05  24.2  32.2  27.4    88.0   0.0  7.7   4.0  280.0
#
#    ff_avg ddd_car
# 0     1.0      SE
# 1     0.0      C
# 2     1.0      C
# 3     1.0      C
# 4     1.0      C

# %%
data2.shape
# Out:
# (342, 10)

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 10 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tn       342 non-null    float64
#  1   Tx       342 non-null    float64
#  2   Tavg     342 non-null    float64
#  3   RH_avg   342 non-null    float64
#  4   RR       342 non-null    float64
#  5   ss       342 non-null    float64
#  6   ff_x     342 non-null    float64
#  7   ddd_x    342 non-null    float64
#  8   ff_avg   342 non-null    float64
#  9   ddd_car  342 non-null    int64
# dtypes: float64(9), int64(1)
# memory usage: 26.8 KB

# %%
data2.describe()
# Out:
#                Tn          Tx        Tavg      RH_avg          RR          ss  \
# count  342.000000  342.000000  342.000000  342.000000  342.000000  342.000000
# mean    24.245906   32.101170   27.354094   87.926901    7.159942    4.622807
# std      0.635391    1.567222    0.921540    4.295252   14.549082    3.081818
# min     22.200000   25.900000   24.700000   74.000000    0.000000    0.000000
# 25%     23.800000   31.400000   26.700000   85.000000    0.000000    1.925000
# 50%     24.200000   32.200000   27.450000   88.000000    0.950000    4.400000
# 75%     24.700000   33.200000   28.000000   90.750000    7.175000    7.000000
# max     26.100000   35.600000   29.900000   99.000000  103.400000   10.800000
#
#             ff_x       ddd_x      ff_avg     ddd_car
# count  342.00000  342.000000  342.000000  342.000000
# mean     3.51462  217.520468    0.967836    0.423977
# std      1.00647   92.846188    0.486312    1.250834
# min      0.00000   10.000000    0.000000    0.000000
# ...

# %%
jumlah_rr_0 = (data2['RR'] == 0).sum()
print(f"Jumlah data dengan RR = 0: {jumlah_rr_0}")
# Out:
# Jumlah data dengan RR = 0: 131

# %%
import plotly.graph_objects as go
from plotly.subplots import make_subplots

# Filter data2 masing-masing tahun
data2_2023 = data2[data2['Tanggal'].dt.year == 2023]
data2_2024 = data2[data2['Tanggal'].dt.year == 2024]

# Titik tertinggi setiap tahun
max_2023 = data2_2023.loc[data2_2023['RR'].idxmax()]
max_2024 = data2_2024.loc[data2_2024['RR'].idxmax()]

# Buat subplot atas-bawah (2 baris, 1 kolom)
fig = make_subplots(
    rows=2, cols=1,
    subplot_titles=("Curah Hujan Tahun 2023", "Curah Hujan Tahun 2024"),
    shared_xaxes=False
)

# Garis tren 2023
fig.add_trace(go.Scatter(
    x=data2_2023['Tanggal'],
    y=data2_2023['RR'],
    mode='lines',
    name='Curah Hujan 2023',
    line=dict(color='blue')
), row=1, col=1)

# Titik tertinggi 2023
fig.add_trace(go.Scatter(
    x=[max_2023['Tanggal']],
    y=[max_2023['RR']],
    mode='markers+text',
    name='Tertinggi 2023',
    marker=dict(color='blue', size=10),
    text=['Tertinggi 2023'],
    textposition='middle right'
), row=1, col=1)

# Garis tren 2024
fig.add_trace(go.Scatter(
    x=data2_2024['Tanggal'],
    y=data2_2024['RR'],
    mode='lines',
    name='Curah Hujan 2024',
    line=dict(color='green')
), row=2, col=1)

# Titik tertinggi 2024
fig.add_trace(go.Scatter(
    x=[max_2024['Tanggal']],
    y=[max_2024['RR']],
    mode='markers+text',
    name='Tertinggi 2024',
    marker=dict(color='green', size=10),
    text=['Tertinggi 2024'],
    textposition='middle right'
), row=2, col=1)

# Layout
fig.update_layout(
    title='Perbandingan Curah Hujan Tahun 2023 dan 2024',
    height=700,
    width=900,
    showlegend=False,
    yaxis_title='Curah Hujan (mm)',
    template='plotly_white'
)

# Format tanggal dan rotasi
fig.update_xaxes(tickformat='%d-%m-%Y', tickangle=-45)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 5
#       2 from plotly.subplots import make_subplots
#       4 # Filter data2 masing-masing tahun
# ----> 5 data2_2023 = data2[data2['Tanggal'].dt.year == 2023]
#       6 data2_2024 = data2[data2['Tanggal'].dt.year == 2024]
#       8 # Titik tertinggi setiap tahun
#
# File ~\anaconda3\envs\Sentiment\Lib\site-packages\pandas\core\generic.py:6299, in NDFrame.__getattr__(self, name)
#    6292 if (
#    6293     name not in self._internal_names_set
#    6294     and name not in self._metadata
#    6295     and name not in self._accessors
#    6296     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6297 ):
#    6298     return self[name]
# -> 6299 return object.__getattribute__(self, name)
#
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 342 entries, 0 to 341
# Data columns (total 11 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Tanggal  342 non-null    datetime64[ns]
#  1   Tn       342 non-null    float64
#  2   Tx       342 non-null    float64
#  3   Tavg     342 non-null    float64
#  4   RH_avg   342 non-null    float64
#  5   RR       342 non-null    float64
#  6   ss       342 non-null    float64
#  7   ff_x     342 non-null    float64
#  8   ddd_x    342 non-null    float64
#  9   ff_avg   342 non-null    float64
#  10  ddd_car  342 non-null    object
# dtypes: datetime64[ns](1), float64(9), object(1)
# memory usage: 29.5+ KB
